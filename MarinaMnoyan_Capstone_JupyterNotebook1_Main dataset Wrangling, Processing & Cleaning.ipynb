# %% [markdown]
# # Capstone Project: "Transforming Neighborhoods by Predicting Crime Outcomes in the UK
# # Name: Marina Mnoyan
# # Contact: marina.mnoyan@gmail.com
# # Date: July 4, 2022
# # Project Purpose:
# Help policymakers to identify and address the factors that influence whether crimes are solved. The main dataset was downloaded from the UK Police Department website. Additional datasets were acquired from various UK Government sources in order to provide neighborhood-level characteristics.
#
#
# # Project Framework & Deliverables
#
#     1. Data Acquisition, pre-processing with MS Excel & Git Bash       MS Excel, Git Bash (details in the ReadMe text file)         2. Main dataset Wrangling, Processing & Cleaning                   Jupyter Notebook 1     <== current notebook
#     3. Additional dataset Merging, Wrangling, Processing & Cleaning    Jupyter Notebook 2
#     4. Exploratory Data Analysis & Visualizations                      Jupyter Notebook 3
#                                                                        Tableau File
#     5. Feature Engineering                                             Jupyter Notebook 4
#     6. Modeling & Evaluation                                           Jupyter Notebook 5
#     7. Findings & Recommendations                                      PDF Business Report
#                                                                        PDF Presentation
#     8. Additional Information including links to original data         ReadMe text file

# %% [markdown]
# # Jupyter Notebook 1 of 5: Main dataset Wrangling, Processing & Cleaning
#
# Steps:
#
# [1) Data Reading and Basic Checks ](#1)
#
# [2) Data Cleaning and Processing](#2)
#
# [3) CSV Output](#3)

# %% [markdown]
# <a id='1'></a>
# ## 1) Data Reading & Basic Checks

# %% [markdown]
# First, we will import basic packages that will help with this deliverable:

# %%
# Import basic data science packages
import numpy as np
import pandas as pd

# Filter warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Then we need to make CSV files readable for Jupyter Notebook. Please note that some pre-processing was done with Git Bash to combine separate downloaded files into one CSV file (details in the ReadMe text file).

# %%
# Importing the CSV file
df_crime = pd.read_csv('data/combined-csv-files-crime.csv')

# %% [markdown]
# Now, let's perform some basic checks to familiarize ourselves with the data.

# %% [markdown]
# First, let's take a peak at what it looks like:

# %%
# Show the first five rows of the dataset
df_crime.head()
# Out:
#                                             Crime ID    Month  \
# 0  f7f56767d4e4c717f500a1ccdb8754151a33598f98e209...  2019-04
# 1                                                NaN  2019-04
# 2                                                NaN  2019-04
# 3                                                NaN  2019-04
# 4  a13ac1b5a26d154227c2d6c0cf3e3db1f1d39b54f93f7d...  2019-04
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -0.837531
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.512153
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.513718
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.509126
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.511927
#
#     Latitude                     Location  LSOA code  \
# 0  51.827141     On or near Carlton Close  E01017707
# 1  51.412941  On or near Heathfield Close  E01014399
# 2  51.429407             On or near A4174  E01014399
# 3  51.416137   On or near St Francis Road  E01014399
# 4  51.409435     On or near Harlech Close  E01014399
#
#                            LSOA name                    Crime type  \
# 0                Aylesbury Vale 012C  Violence and sexual offences
# 1  Bath and North East Somerset 001A         Anti-social behaviour
# 2  Bath and North East Somerset 001A         Anti-social behaviour
# 3  Bath and North East Somerset 001A         Anti-social behaviour
# 4  Bath and North East Somerset 001A                      Burglary
#
#        Last outcome category Context
# 0  Status update unavailable     NaN
# 1                        NaN     NaN
# 2                        NaN     NaN
# 3                        NaN     NaN
# 4  Status update unavailable     NaN

# %% [markdown]
# We can see that we are dealing with missing data in some of the columns, however no duplication has been noticed. We'll need to check the percentage of missing values to see which columns we can keep, and what kind of analysis we can perform.
#
# There are also columns which may not be useful for the scope of our analysis which we may consider dropping later.
#
# Here are descriptions of the columns:
#
# * **Crime ID:**                 A unique ID given to each crime in the neighborhood
# * **Month:**                    A Month/Year combination of when the crime was committed
# * **Report by:**                Police Jurisdiction that reported the Crime
# * **Falls within:**             Police Jurisdiction where the crime occurred
# * **Longitude:**                Longitude where crime occurred
# * **Latitude:**                 Latitude where crime occurred
# * **Location:**                 Intersection or particular location of where the crime occurred
# * **LSOA code:**                Neighborhood code
# * **LSOA name:**                Neighborhood name
# * **Crime type:**               Type of crime committed
# * **Last outcome category:**    Outcome of the investigation
# * **Context:**                  Additional information

# %% [markdown]
# Next, let's check how big our dataset is:

# %%
# Returns the number of rows and columns
df_crime.shape
# Out:
# (19003667, 12)

# %% [markdown]
# Look like the dataset has over 1.9MM rows and 12 columns. It is a quite large dataset which may need a lot of computational power, so we may need to come up with a way to reduce it.

# %% [markdown]
# Now let's look at how many columns have missing data:

# %%
# Shows the # of rows with missing data
df_crime.isnull().sum()
# Out:
# Crime ID                  4635413
# Month                           1
# Reported by                     1
# Falls within                    1
# Longitude                  355458
# Latitude                   355458
# Location                        1
# LSOA code                  841365
# LSOA name                  841365
# Crime type                      1
# Last outcome category     4932023
# Context                  19002084
# dtype: int64

# %% [markdown]
# Looks like quite a lot of the data is missing but let's look at it in terms of percentages:

# %%
print("The percentage of null rows: ", df_crime.isnull().sum() / len(df_crime) * 100)
# Out:
# The percentage of null rows:  Crime ID                 24.392203
# Month                     0.000005
# Reported by               0.000005
# Falls within              0.000005
# Longitude                 1.870471
# Latitude                  1.870471
# Location                  0.000005
# LSOA code                 4.427382
# LSOA name                 4.427382
# Crime type                0.000005
# Last outcome category    25.953007
# Context                  99.991670
# dtype: float64

# %% [markdown]
# Unfortunately, it looks like the `Context` column is missing 99% of its data so we cannot use NLP to do sentiment analysis. Additional columns with large proportions of missing values are `Last Outcome Category` and `Crime ID`.
#
# We will not really need Crime ID for our analysis so can safely drop the column.  However, Last Outcome Category is our dependent variable so we will drop the observations with missing values rather than try to impute it as it will mess up with our analysis and modeling.
#
# Given the size of the dataset and relatively small proportion of missing data in other columns, we will just drop the rows with missing values.

# %% [markdown]
# Now, let's see how many duplicated rows we have (we can already see that columns are not duplicated):

# %%
# Checking the number of duplicated rows
df_crime.duplicated().sum()
# Out:
# 1749722

# %%
# Printing the percentage of duplicated rows
print("The percentage of duplicated rows: ", df_crime.duplicated().sum() / len(df_crime) * 100)
# Out:
# The percentage of duplicated rows:  9.207286151667466

# %% [markdown]
# It looks like over 9% of rows are duplicated. Before dropping them, it would be good to check whether these are the ones that have the Crime ID (meaning they are true duplicates) and don't have Crime ID (meaning that they may not be duplicates, and just similar crimes occurring):

# %%
# Selecting duplicate rows except first
# Occurrence based on all columns
duplicate = df_crime[df_crime.duplicated()]
 
print("Duplicate Rows:")
 
# Print the resultant Dataframe
duplicate.head(50)
# Out:
# Duplicate Rows:
# 406  Bath and North East Somerset 007F  Anti-social behaviour
# 407  Bath and North East Somerset 007F  Anti-social behaviour
# 454  Bath and North East Somerset 009C  Anti-social behaviour
# 455  Bath and North East Somerset 009C  Anti-social behaviour
# 459  Bath and North East Somerset 009C  Anti-social behaviour
# 460  Bath and North East Somerset 009C  Anti-social behaviour
# 489  Bath and North East Somerset 009E  Anti-social behaviour
# 491  Bath and North East Somerset 009E  Anti-social behaviour
# 530  Bath and North East Somerset 010A  Anti-social behaviour
# 571  Bath and North East Somerset 011B  Anti-social behaviour
# 572  Bath and North East Somerset 011B  Anti-social behaviour
# 593  Bath and North East Somerset 011D  Anti-social behaviour
# 594  Bath and North East Somerset 011D  Anti-social behaviour
# 683  Bath and North East Somerset 013C  Anti-social behaviour
# 684  Bath and North East Somerset 013C  Anti-social behaviour
# 686  Bath and North East Somerset 013C  Anti-social behaviour
# 730  Bath and North East Somerset 014C  Anti-social behaviour
# 742  Bath and North East Somerset 015A  Anti-social behaviour
# 744  Bath and North East Somerset 015A  Anti-social behaviour
# 745  Bath and North East Somerset 015A  Anti-social behaviour
# 791  Bath and North East Somerset 016C  Anti-social behaviour
# 792  Bath and North East Somerset 016C  Anti-social behaviour
# 793  Bath and North East Somerset 016C  Anti-social behaviour
# 794  Bath and North East Somerset 016C  Anti-social behaviour
# 878  Bath and North East Somerset 018C           Public order
# 883  Bath and North East Somerset 018D  Anti-social behaviour
# 884  Bath and North East Somerset 018D  Anti-social behaviour
# 911  Bath and North East Somerset 019D  Anti-social behaviour
#
#          Last outcome category Context
# 14                         NaN     NaN
# 17                         NaN     NaN
# 18                         NaN     NaN
# 20                         NaN     NaN
# 21                         NaN     NaN
# 22                         NaN     NaN
# 23                         NaN     NaN
# 57                         NaN     NaN
# 84                         NaN     NaN
# 85                         NaN     NaN
# 87                         NaN     NaN
# 88                         NaN     NaN
# 161                        NaN     NaN
# 163                        NaN     NaN
# 170                        NaN     NaN
# 200                        NaN     NaN
# 203                        NaN     NaN
# 208                        NaN     NaN
# 322                        NaN     NaN
# 326                        NaN     NaN
# 380  Status update unavailable     NaN
# 405                        NaN     NaN
# 406                        NaN     NaN
# 407                        NaN     NaN
# 454                        NaN     NaN
# 455                        NaN     NaN
# 459                        NaN     NaN
# 460                        NaN     NaN
# 489                        NaN     NaN
# 491                        NaN     NaN
# 530                        NaN     NaN
# 571                        NaN     NaN
# 572                        NaN     NaN
# 593                        NaN     NaN
# 594                        NaN     NaN
# 683                        NaN     NaN
# 684                        NaN     NaN
# 686                        NaN     NaN
# 730                        NaN     NaN
# 742                        NaN     NaN
# 744                        NaN     NaN
# 745                        NaN     NaN
# 791                        NaN     NaN
# 792                        NaN     NaN
# 793                        NaN     NaN
# 794                        NaN     NaN
# 878  Status update unavailable     NaN
# 883                        NaN     NaN
# 884                        NaN     NaN
# 911                        NaN     NaN

# %% [markdown]
# Looking at the duplicated rows, it looks like many of them are missing the Crime ID. Additionally, the Committed Crimes are generally related to Public Order and Anti-social behavior. Since these crimes tend to involve more than one individual, we will not drop the duplicates and will treat them as unique entries.

# %% [markdown]
# Lastly, let's check our column types:

# %%
# Checking column dtype
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19003667 entries, 0 to 19003666
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Crime ID               object
#  1   Month                  object
#  2   Reported by            object
#  3   Falls within           object
#  4   Longitude              object
#  5   Latitude               object
#  6   Location               object
#  7   LSOA code              object
#  8   LSOA name              object
#  9   Crime type             object
#  10  Last outcome category  object
#  11  Context                object
# dtypes: object(12)
# memory usage: 1.7+ GB

# %% [markdown]
# Looks like there is an opportunity to separate the month and the year and cast them as integers, as well as change longitude and latitude to floats.

# %% [markdown]
# <a id='2'></a>
# ## 2) Data Cleaning & Processing

# %% [markdown]
# First of all, let's start looking at the columns. First let's see if there is a big difference between `Reported by` and `Falls within` columns, i.e. if we need both of them or just one:

# %%
# Checking the percent of 'sameness': 
(df_crime['Reported by'] == df_crime['Falls within']).mean()
# Out:
# 0.9999166476659478

# %% [markdown]
# Looks like the columns have a very significant overlap.

# %% [markdown]
# At this point we can make the decision to drop the following columns:
#
# * `Crime ID`: It has a lot of missing values and will likely not be useful in our future analysis
# * `Context`: It has 99% missing values
# * `Location`: While this is great data for a more granular analysis, additional demographic datasets are available on the neighborhood (LSOA) level only, so we will drop this column for now. It can be used in future analyses.
# * `Falls within`: Since there is a 99.99% overlap between this column and `Reported  by` column, we can safely drop it

# %%
# Dropping the columns
df_crime.drop(columns=['Crime ID', 'Context', 'Falls within', 'Location'], inplace=True)

# %% [markdown]
# We will also rename the `Reported by` column into `Police Jurisdiction` for ease of understanding

# %%
# Renaming
df_crime.rename(columns = {'Reported by':'Police_Jurisdiction'}, inplace = True)

# %% [markdown]
# Let's do a sanity check to make sure everything is ok:

# %%
# Viewing the first 5 rows
df_crime.head()
# Out:
#      Month             Police_Jurisdiction  Longitude   Latitude  LSOA code  \
# 0  2019-04  Avon and Somerset Constabulary  -0.837531  51.827141  E01017707
# 1  2019-04  Avon and Somerset Constabulary  -2.512153  51.412941  E01014399
# 2  2019-04  Avon and Somerset Constabulary  -2.513718  51.429407  E01014399
# 3  2019-04  Avon and Somerset Constabulary  -2.509126  51.416137  E01014399
# 4  2019-04  Avon and Somerset Constabulary  -2.511927  51.409435  E01014399
#
#                            LSOA name                    Crime type  \
# 0                Aylesbury Vale 012C  Violence and sexual offences
# 1  Bath and North East Somerset 001A         Anti-social behaviour
# 2  Bath and North East Somerset 001A         Anti-social behaviour
# 3  Bath and North East Somerset 001A         Anti-social behaviour
# 4  Bath and North East Somerset 001A                      Burglary
#
#        Last outcome category
# 0  Status update unavailable
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4  Status update unavailable

# %% [markdown]
# Everything looks ok.

# %% [markdown]
# Now that we have our columns, let's drop the null values. This will also help reduce the size of the file:

# %%
# Dropping null values
df_crime.dropna(inplace=True)

# %% [markdown]
# Now, we can separate the current `Month` column into separate `Year` and `Month` columns:

# %%
# Extracting the year portion (before the hyphen) into the Year column
df_crime['Year'] = df_crime['Month'].str.split('-', expand=True)[0]

# %%
# Extracting the month portion (before the hyphen) into the Year column
df_crime['Month'] = df_crime['Month'].str.split('-', expand=True)[1]

# %% [markdown]
# Checking that this worked:

# %%
# Looking at first five rows
df_crime.head()
# Out:
#   Month             Police_Jurisdiction  Longitude   Latitude  LSOA code  \
# 0    04  Avon and Somerset Constabulary  -0.837531  51.827141  E01017707
# 4    04  Avon and Somerset Constabulary  -2.511927  51.409435  E01014399
# 5    04  Avon and Somerset Constabulary  -2.515072  51.419357  E01014399
# 6    04  Avon and Somerset Constabulary  -2.516919  51.423683  E01014399
# 7    04  Avon and Somerset Constabulary  -2.515072  51.419357  E01014399
#
#                            LSOA name                    Crime type  \
# 0                Aylesbury Vale 012C  Violence and sexual offences
# 4  Bath and North East Somerset 001A                      Burglary
# 5  Bath and North East Somerset 001A                      Burglary
# 6  Bath and North East Somerset 001A                  Public order
# 7  Bath and North East Somerset 001A                 Vehicle crime
#
#        Last outcome category  Year
# 0  Status update unavailable  2019
# 4  Status update unavailable  2019
# 5  Status update unavailable  2019
# 6  Status update unavailable  2019
# 7  Status update unavailable  2019

# %% [markdown]
# This worked! There are some problems with the index but we can fix it in the end.

# %% [markdown]
# Let's check that we didn't introduce any null values by performing the split:

# %%
# Checking for the number of rows containing null values
df_crime.isna().sum()
# Out:
# Month                    1583
# Police_Jurisdiction         0
# Longitude                   0
# Latitude                    0
# LSOA code                   0
# LSOA name                   0
# Crime type                  0
# Last outcome category       0
# Year                        0
# dtype: int64

# %% [markdown]
# Looks like there are some small missing values in the Month category, let's drop them:

# %%
# Droppping null rows
df_crime.dropna(inplace=True)

# %% [markdown]
# Now let's change the `Month` and `Year` columns into integers to help with future EDA:

# %%
# Casting Month as integer
df_crime['Month'] = df_crime['Month'].astype(int)

# %%
# Casting Year as integer
df_crime['Year'] = df_crime['Year'].astype(int)

# %% [markdown]
# Performing sanity check:

# %%
# Checking Dtype of each column
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13738495 entries, 0 to 19003665
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Month                  int32
#  1   Police_Jurisdiction    object
#  2   Longitude              object
#  3   Latitude               object
#  4   LSOA code              object
#  5   LSOA name              object
#  6   Crime type             object
#  7   Last outcome category  object
#  8   Year                   int32
# dtypes: int32(2), object(7)
# memory usage: 943.3+ MB

# %% [markdown]
# Success!

# %% [markdown]
# While we would have loved to continue working with the full database, unfortunately this takes too long to run and crashed the laptop repeatedly. With this, we will extract the latest full year (year=2021) of information to move to the next step of our project:

# %%
# Extracting all rows where Year is 2021
df_crime = df_crime[(df_crime['Year']==2021)]

# %% [markdown]
# With this we don't really need the `Year` column anymore:

# %%
# Dropping the year column
df_crime.drop(axis=1, columns='Year', inplace=True)

# %% [markdown]
# Now we can change the type of our geographic data from object to float:

# %%
# Changing Longitude into a float
df_crime["Longitude"] = pd.to_numeric(df_crime["Longitude"], downcast="float")

# %%
# Changing Latitude into a float
df_crime["Latitude"] = pd.to_numeric(df_crime["Latitude"], downcast="float")

# %% [markdown]
# Let's check that this worked!

# %%
# Checking the Dtype of each column
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4580733 entries, 11301432 to 17545961
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Month                  int32
#  1   Police_Jurisdiction    object
#  2   Longitude              float32
#  3   Latitude               float32
#  4   LSOA code              object
#  5   LSOA name              object
#  6   Crime type             object
#  7   Last outcome category  object
# dtypes: float32(2), int32(1), object(5)
# memory usage: 262.1+ MB

# %% [markdown]
# Everything worked as planned.

# %% [markdown]
# <a id='1'></a>
# ## CSV Output

# %% [markdown]
# Prior to outputting the cleaned file as CSV, let's check where we are and reset the index:

# %%
# Looking at first 5 rows
df_crime.head()
# Out:
#           Month             Police_Jurisdiction  Longitude   Latitude  \
# 11301432      1  Avon and Somerset Constabulary  -2.515072  51.419357
# 11301433      1  Avon and Somerset Constabulary  -2.494870  51.422276
# 11301434      1  Avon and Somerset Constabulary  -2.494870  51.422276
# 11301435      1  Avon and Somerset Constabulary  -2.511927  51.409435
# 11301436      1  Avon and Somerset Constabulary  -2.511761  51.409966
#
#           LSOA code                          LSOA name  \
# 11301432  E01014399  Bath and North East Somerset 001A
# 11301433  E01014399  Bath and North East Somerset 001A
# 11301434  E01014399  Bath and North East Somerset 001A
# 11301435  E01014399  Bath and North East Somerset 001A
# 11301436  E01014399  Bath and North East Somerset 001A
#
#                             Crime type        Last outcome category
# 11301432                      Burglary    Status update unavailable
# 11301433     Criminal damage and arson    Status update unavailable
# 11301434     Criminal damage and arson    Status update unavailable
# 11301435                  Public order  Unable to prosecute suspect
# 11301436  Violence and sexual offences  Unable to prosecute suspect

# %%
df_crime.shape
# Out:
# (4580733, 8)

# %% [markdown]
# We ended up with ~4MM observations and 8 columns to move into the next step of our project. Now let's reset the index

# %%
# Resetting the index
df_crime.reset_index(drop=True)
# Out:
#          Month             Police_Jurisdiction  Longitude   Latitude  \
# 0            1  Avon and Somerset Constabulary  -2.515072  51.419357
# 1            1  Avon and Somerset Constabulary  -2.494870  51.422276
# 2            1  Avon and Somerset Constabulary  -2.494870  51.422276
# 3            1  Avon and Somerset Constabulary  -2.511927  51.409435
# 4            1  Avon and Somerset Constabulary  -2.511761  51.409966
# ...        ...                             ...        ...        ...
# 4580728     12                Wiltshire Police  -1.751553  50.992847
# 4580729     12                Wiltshire Police  -1.743673  50.993011
# 4580730     12                Wiltshire Police  -1.739677  50.994244
# 4580731     12                Wiltshire Police  -1.757983  50.992241
# 4580732     12                Wiltshire Police  -1.757983  50.992241
#
#          LSOA code                          LSOA name  \
# 0        E01014399  Bath and North East Somerset 001A
# 1        E01014399  Bath and North East Somerset 001A
# 2        E01014399  Bath and North East Somerset 001A
# 3        E01014399  Bath and North East Somerset 001A
# 4        E01014399  Bath and North East Somerset 001A
# ...            ...                                ...
# 4580728  E01031995                     Wiltshire 062E
# 4580729  E01031995                     Wiltshire 062E
# 4580730  E01031995                     Wiltshire 062E
# 4580731  E01031995                     Wiltshire 062E
# 4580732  E01031995                     Wiltshire 062E
#
#                            Crime type  \
# 0                            Burglary
# 1           Criminal damage and arson
# 2           Criminal damage and arson
# 3                        Public order
# 4        Violence and sexual offences
# ...                               ...
# 4580728                   Shoplifting
# 4580729                 Vehicle crime
# 4580730                 Vehicle crime
# 4580731  Violence and sexual offences
# 4580732  Violence and sexual offences
#
#                                  Last outcome category
# 0                            Status update unavailable
# 1                            Status update unavailable
# 2                            Status update unavailable
# 3                          Unable to prosecute suspect
# 4                          Unable to prosecute suspect
# ...                                                ...
# 4580728  Investigation complete; no suspect identified
# 4580729  Investigation complete; no suspect identified
# 4580730  Investigation complete; no suspect identified
# 4580731                    Unable to prosecute suspect
# 4580732                    Unable to prosecute suspect
#
# [4580733 rows x 8 columns]

# %% [markdown]
# At this point we are ready to export the processed file into a CSV, to be picked up in Jupyter Notebook 2:

# %%
df_crime.to_csv(r'data\df_crime.csv', index=False)

# %% [markdown]
# ### This is the end of Jupyter Notebook 1 (of 5). Please proceed to Jupyter Notebook 2.
